# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_vs_nstars(band,nside,sky):
    mean, var, nstars = np.loadtxt('./nLBGs_per_n_rand-nstar_%s-band_nside%d_%s.dat'%(band, nside, sky), delimiter=' ',unpack=True)
    std = np.sqrt(var)
    #plt.title(r'$%s-band n_{\rm LBGs}/n_{\rm random}$ vs. $n_{\rm stars}$ for $n_{\rm side} = %d$ at %s'%(band, nside, sky))
    plt.xlabel(r'$n_{\rm stars} {\rm [/deg^2]}$')
    plt.ylabel(r'$n_{\rm LBGs}/n_{\rm random}$')
    #plt.xlim([0.,1000.])
    plt.ylim([-1.,3])
    plt.errorbar(nstars, mean, yerr=std, fmt='.',label=sky)
    #plt.xscale('log')
    plt.legend()
    #plt.show()
    
def plot_vs_extendedness0(band,nside,sky):
    mean, var, nstars = np.loadtxt('./nLBGs_per_n_rand-extendedness0_%s-band_nside%d_%s.dat'%(band, nside, sky), delimiter=' ',unpack=True)
    std = np.sqrt(var)
    #plt.title(r'$%s-band n_{\rm LBGs}/n_{\rm random}$ vs. $n_{\rm stars}$ for $n_{\rm side} = %d$ at %s'%(band, nside, sky))
    plt.xlabel(r'$n_{\rm stars} {\rm [/deg^2]}$')
    plt.ylabel(r'$n_{\rm LBGs}/n_{\rm random}$')
    #plt.xlim([0.,1000.])
    plt.ylim([-1.,3])
    plt.errorbar(nstars, mean, yerr=std, fmt='.',label=sky)
    #plt.xscale('log')
    plt.legend()
    #plt.show()
    
def plot_vs_fluxsigma2(band,nside,sky):
    mean, var, sigma2 = np.loadtxt('./nLBGs_per_n_rand-fluxsigma2_%s-band_nside%d_%s.dat'%(band, nside, sky), delimiter=' ',unpack=True)
    std = np.sqrt(var)
    #plt.title(r'%s-band $n_{\rm LBGs}/n_{\rm random}$ vs. $<\sigma^2>$ for $n_{\rm side} = %d$ at %s'%(band, nside, sky))
    plt.xlabel(r'$<\sigma^2>$')
    plt.ylabel(r'$n_{\rm LBGs}/n_{\rm random}$')
    #plt.xlim([0.,1000.])
    #plt.ylim([-1.,3])
    plt.errorbar(sigma2, mean, yerr=std, fmt='.', label=sky)
    plt.xscale('log')
    plt.legend()
    #plt.show()
    
def plot_vs_i_sdss_seeing(band,nside,sky):
    mean, var, sigma2 = np.loadtxt('./nLBGs_per_n_rand-sdss_seeing_%s-band_nside%d_%s.dat'%(band, nside, sky), delimiter=' ',unpack=True)
    std = np.sqrt(var)
    plt.title(r'%s-band $n_{\rm LBGs}/n_{\rm random}$ vs. FWHM for $n_{\rm side} = %d at %s$'%(band, nside, sky))
    plt.xlabel(r'FWHM')
    plt.ylabel(r'$n_{\rm LBGs}/n_{\rm random}$')
    #plt.xlim([0.,1000.])
    #plt.ylim([-1.,3])
    plt.errorbar(sigma2, mean, yerr=std, fmt='.')
    plt.show()

# %%
plot_vs_nstars('g',256, 'W02')
plot_vs_nstars('g',256, 'W03')
plot_vs_nstars('g',256, 'W04')
plot_vs_nstars('g',256, 'W05')
plot_vs_nstars('g',256, 'W06')
plot_vs_nstars('g',256, 'W07')

# %%
plot_vs_nstars('r',256, 'W02')
plot_vs_nstars('r',256, 'W03')
plot_vs_nstars('r',256, 'W04')
plot_vs_nstars('r',256, 'W05')
plot_vs_nstars('r',256, 'W06')
plot_vs_nstars('r',256, 'W07')

# %%
plot_vs_nstars('i',256, 'W02')
plot_vs_nstars('i',256, 'W03')
plot_vs_nstars('i',256, 'W04')
plot_vs_nstars('i',256, 'W05')
plot_vs_nstars('i',256, 'W06')
plot_vs_nstars('i',256, 'W07')

# %%
plot_vs_fluxsigma2('g',256, 'W02')
plot_vs_fluxsigma2('g',256, 'W03')
plot_vs_fluxsigma2('g',256, 'W04')
plot_vs_fluxsigma2('g',256, 'W05')
plot_vs_fluxsigma2('g',256, 'W06')
plot_vs_fluxsigma2('g',256, 'W07')

# %%
plot_vs_fluxsigma2('r',256, 'W02')
plot_vs_fluxsigma2('r',256, 'W03')
plot_vs_fluxsigma2('r',256, 'W04')
plot_vs_fluxsigma2('r',256, 'W05')
plot_vs_fluxsigma2('r',256, 'W06')
plot_vs_fluxsigma2('r',256, 'W07')

# %%
plot_vs_fluxsigma2('i',256, 'W02')
plot_vs_fluxsigma2('i',256, 'W03')
plot_vs_fluxsigma2('i',256, 'W04')
plot_vs_fluxsigma2('i',256, 'W05')
plot_vs_fluxsigma2('i',256, 'W06')
plot_vs_fluxsigma2('i',256, 'W07')

# %%
'''
plot_vs_extendedness0('i',256, 'W02')
plot_vs_extendedness0('i',256, 'W03')
plot_vs_extendedness0('i',256, 'W04')
plot_vs_extendedness0('i',256, 'W05')
plot_vs_extendedness0('i',256, 'W06')
plot_vs_extendedness0('i',256, 'W07')
'''
# Out:
# "\nplot_vs_extendedness0('i',256, 'W02')\nplot_vs_extendedness0('i',256, 'W03')\nplot_vs_extendedness0('i',256, 'W04')\nplot_vs_extendedness0('i',256, 'W05')\nplot_vs_extendedness0('i',256, 'W06')\nplot_vs_extendedness0('i',256, 'W07')\n"

# %%
plot_vs_i_sdss_seeing('i',256, 'W02')
plot_vs_i_sdss_seeing('i',256, 'W03')
plot_vs_i_sdss_seeing('i',256, 'W04')
plot_vs_i_sdss_seeing('i',256, 'W05')
plot_vs_i_sdss_seeing('i',256, 'W06')
plot_vs_i_sdss_seeing('i',256, 'W07')

# %%
import healpy as hp
area= hp.nside2pixarea(256,degrees=True)
print(area)
# Out:
# 0.052455852825697924
